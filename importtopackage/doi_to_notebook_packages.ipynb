# %%
import json

with open("shared.json") as f:
    dois = json.load(f)

# %%
import sqlite3
# Dataset of a Study of Computational reproducibility of Jupyter notebooks from biomedical publications
# https://zenodo.org/records/8226725
con = sqlite3.connect("../../hackathon/computational-reproducibility-pmc/computational-reproducibility-pmc/analyses/db.sqlite")
cur = con.cursor()

# %%
from operator import or_
from functools import reduce

class Hashabledict(dict):
    def __hash__(self):
        return hash(frozenset(self))

imports_in_notebooks_by_doi = {}
for doi in dois:
    res = cur.execute("""
        select m.external_any, n.name from notebook_modules m
        inner join notebooks n on (m.notebook_id = n.id and m.repository_id = n.repository_id)
        inner join repositories r on (r.id = m.repository_id)
        inner join article a on (a.id = r.article_id)
        where a.doi = ?
    """, (doi,))
    imports_in_notebooks_by_doi[doi] = reduce(or_, [
        {Hashabledict({
            'local': -1, # unknown
            'filename': x[1], 
            'filetype': 'notebook',
            'name': package.split('.')[0]
        }) for package in x[0].split(',') if package.split('.')[0]}
        for x in res.fetchall()], set())

# %%
from extract_packages import import_data_to_package, PackageExtractorConfig
config = PackageExtractorConfig(use_bq=True)

# %%
packages_in_notebooks_by_doi = {}


for doi, imports in imports_in_notebooks_by_doi.items():
    packages = import_data_to_package(imports, config=config)
    packages_in_notebooks_by_doi[doi] = packages

# %%
from collections import defaultdict
simplified_packages_by_doi = defaultdict(set)
unknown_packages_by_doi = defaultdict(set)
for doi, packages in packages_in_notebooks_by_doi.items():
    for package in packages:
        if package['mode'] == 'unknown':
            unknown_packages_by_doi[doi].add(package['importname'])
        elif package['name'] != '<builtin>':
            simplified_packages_by_doi[doi].add(package['name'])

# %%
len(reduce(or_, unknown_packages_by_doi.values()))
# Out:
# 467

# %%
len(reduce(or_, simplified_packages_by_doi.values()))
# Out:
# 911

# %%
simplified_packages_by_doi
# Out:
# defaultdict(set,
#             {'10.15252/msb.20199235': {'cobra'},
#              '10.1021/acs.jcim.1c00428': {'numpy'},
#              '10.1186/s40462-021-00268-4': {'Cartopy',
#               'Fiona',
#               'GPU-BSM',
#               'Shapely',
#               'geopandas',
#               'geoplot',
#               'hvplot',
#               'matplotlib',
#               'movingpandas',
#               'numpy',
#               'osgeo',
#               'pandas',
#               'requests',
#               'scikit-learn',
#               'tqdm',
#               'viresclient'},
#              '10.1093/hmg/ddaa212': {'UpSetPlot',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1093/bioinformatics/btaa578': {'autoreload',
#               'biopython',
#               'functions',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1074/jbc.M116.767616': {'PyYAML',
#               'matplotlib',
#               'numpy',
#               'scipy'},
#              '10.1111/gwat.12925': {'corner',
#               'emcee',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pastas',
#               'scipy',
#               'timml'},
#              '10.1093/gigascience/gix013': {'Pillow',
#               'dipy',
#               'fury',
#               'graspy',
#               'm2g',
#               'matplotlib',
#               'ndmg',
#               'networkx',
#               'nibabel',
#               'nilearn',
#               'numpy',
#               'scipy'},
#              '10.7554/eLife.66410': {'colorcet',
#               'matplotlib',
#               'numpy',
#               'scipy',
#               'torch'},
#              '10.3389/fnhum.2021.675433': {'designer',
#               'dipy',
#               'matplotlib',
#               'nibabel',
#               'numpy',
#               'pandas',
#               'pyAFQ',
#               's3fs',
#               'seaborn'},
#              '10.1371/journal.pcbi.1008551': {'DEERPREdict',
#               'MDAnalysis',
#               'matplotlib',
#               'mdtraj',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.12688/f1000research.22292.2': {'matplotlib',
#               'numpy',
#               'rdkit'},
#              '10.1186/s12860-020-00295-w': {'MDAnalysis',
#               'ParmEd',
#               'bokeh',
#               'ipython',
#               'ipywidgets',
#               'mbuild',
#               'mdanalysistests',
#               'mdtraj',
#               'nglview',
#               'numpy',
#               'pandas',
#               'pdb4amber',
#               'plotly',
#               'pytraj',
#               'rdkit'},
#              '10.1200/CCI.19.00127': {'civicpy',
#               'matplotlib',
#               'numpy',
#               'pandas'},
#              '10.1016/j.patter.2021.100315': {'matplotlib',
#               'numpy',
#               'pandas',
#               'statsmodels'},
#              '10.3389/frai.2021.613261': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1098/rsos.201130': {'ipython',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'osmnx',
#               'pandas',
#               'scikit-learn',
#               'scipy'},
#              '10.12688/f1000research.12817.2': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'python-dateutil',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1186/s12918-016-0288-x': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'sympy',
#               'vincent'},
#              '10.7554/eLife.59187': {'3DeeCellTracker',
#               'autoreload',
#               'ipython',
#               'matplotlib'},
#              '10.1093/bioinformatics/btaa971': {'data',
#               'ipython',
#               'ipywidgets',
#               'layers',
#               'loss',
#               'matplotlib',
#               'metric',
#               'numpy',
#               'pandas',
#               'results',
#               'scikit-bio',
#               'scipy',
#               'tensorflow',
#               'train',
#               'utils'},
#              '10.1186/s13059-019-1758-4': {'Pillow',
#               'igraph',
#               'imageio',
#               'ipython',
#               'libroadrunner',
#               'lxml',
#               'matplotlib',
#               'ndex2',
#               'networkx',
#               'numpy',
#               'pandas',
#               'py2cytoscape',
#               'py4cytoscape',
#               'requests',
#               'rpy2',
#               'seaborn',
#               'wget',
#               'xmltodict'},
#              '10.3390/s20041096': {'h2o',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1371/journal.pcbi.1004817': {'biopython',
#               'ipython',
#               'matplotlib',
#               'mpld3',
#               'numpy',
#               'scipy'},
#              '10.1093/bioinformatics/btaa961': {'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'requests',
#               'seaborn'},
#              '10.1038/s41598-019-45752-5': {'baltic',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1016/j.celrep.2020.108122': {'abutils',
#               'matplotlib',
#               'natsort',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1016/j.celrep.2019.03.102': {'Brian2',
#               'autoreload',
#               'matplotlib',
#               'numpy',
#               'pymuvr',
#               'pyranges',
#               'scikit-learn',
#               'scipy',
#               'so',
#               'sympy'},
#              '10.1371/journal.pone.0141298': {'matplotlib',
#               'pandas',
#               'pysam',
#               'scipy',
#               'statsmodels'},
#              '10.1371/journal.pone.0225734': {'Shapely',
#               'geopandas',
#               'matplotlib',
#               'numpy',
#               'osmnx',
#               'pandas',
#               'powerlaw',
#               'pwlf',
#               'pylandstats',
#               'rasterio',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'slugify',
#               'tqdm'},
#              '10.7554/eLife.47314': {'Brian2',
#               'brian2tools',
#               'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'plotly',
#               'scipy',
#               'seaborn'},
#              '10.7554/eLife.23629': {'HTSeq',
#               'biopython',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pyfaidx',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1523/ENEURO.0177-20.2020': {'matplotlib',
#               'numpy',
#               'scikit-learn',
#               'scipy'},
#              '10.1371/journal.pone.0203948': {'cogent',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'seaborn'},
#              '10.7717/peerj.4013': {'biopython',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pbxplore'},
#              '10.1523/ENEURO.0315-18.2018': {'autoreload',
#               'imagej',
#               'ipython',
#               'jnius',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'scyjava',
#               'sympy',
#               'tifffile',
#               'tqdm'},
#              '10.3389/fnins.2018.00468': {'easyeeg',
#               'mne',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'tensorflow'},
#              '10.1186/s40168-021-01083-0': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.3390/v11050439': {'colour',
#               'ipython',
#               'matplotlib',
#               'natsort',
#               'numpy',
#               'pandas',
#               'plotnine',
#               'rpy2',
#               'scipy',
#               'seaborn'},
#              '10.7717/peerj-cs.398': {'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.1186/s12864-021-07447-y': {'biopython',
#               'bioservices',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.3389/frai.2021.582110': {'Pillow',
#               'albumentations',
#               'autoreload',
#               'fastai',
#               'fastprogress',
#               'imutils',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'petl',
#               'scikit-image',
#               'scikit-learn',
#               'tesserocr',
#               'torch',
#               'torchsummary',
#               'torchvision',
#               'tqdm',
#               'unidecode'},
#              '10.1371/journal.pcbi.1007753': {'Cython',
#               'Dot-Plot',
#               'bnpy',
#               'cyrand',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scikit-posthocs',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.3390/biomimetics6020037': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn'},
#              '10.2196/23703': {'langdetect',
#               'matplotlib',
#               'nltk',
#               'numpy',
#               'pandas',
#               'plotly',
#               'pycountry',
#               'scikit-learn',
#               'textblob',
#               'yellowbrick'},
#              '10.1098/rsos.171582': {'bqplot',
#               'ipython',
#               'ipyvolume',
#               'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'scipy'},
#              '10.12688/f1000research.6767.1': {'beautifulsoup4',
#               'bokeh',
#               'igraph',
#               'ipython',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'py2cytoscape',
#               'requests',
#               'rpy2'},
#              '10.1186/s40359-017-0186-z': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'watermark'},
#              '10.3390/e22111274': {'igraph',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'umap-learn'},
#              '10.3389/fphys.2018.00549': {'DSGRN',
#               'graphviz',
#               'ipython',
#               'pychomp'},
#              '10.3389/fpls.2019.01778': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1007/s12559-020-09773-x': {'matplotlib'},
#              '10.1038/sdata.2018.203': {'Cartopy',
#               'Fiona',
#               'Pyomo',
#               'Shapely',
#               'altair',
#               'branca',
#               'folium',
#               'geopandas',
#               'ipython',
#               'kml2geojson',
#               'matplotlib',
#               'numpy',
#               'owslib',
#               'pandas',
#               'requests',
#               'scipy',
#               'vincent'},
#              '10.3390/v12020241': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.1002/jbio.201960050': {'Pillow',
#               'ipython',
#               'keras',
#               'keras-vis',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'rpy2',
#               'scikit-image',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tensorflow',
#               'umap-learn'},
#              '10.3389/fninf.2018.00009': {'Theano',
#               'convis',
#               'litus',
#               'matplotlib',
#               'numpy',
#               'scipy',
#               'stimulus'},
#              '10.7554/eLife.34467': {'ipython',
#               'ipywidgets',
#               'matplotlib',
#               'nelpy',
#               'numpy',
#               'pandas',
#               'requests',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tabulate',
#               'tqdm',
#               'watermark'},
#              '10.1016/j.dib.2020.106047': {'botometer',
#               'classifier',
#               'emoji',
#               'fastprogress',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pymongo',
#               'seaborn',
#               'tweepy',
#               'unidecode'},
#              '10.1523/JNEUROSCI.2751-19.2020': {'autoreject',
#               'ipython',
#               'matplotlib',
#               'mne',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1186/s12864-018-4903-7': {'Jinja2',
#               'autoreload',
#               'biopython',
#               'htmlmin',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pysam',
#               'scipy',
#               'utils'},
#              '10.1007/s10278-018-0079-6': {'Pillow',
#               'albumentations',
#               'grad-cam',
#               'h5py',
#               'ipython',
#               'keras',
#               'matplotlib',
#               'mdai',
#               'monai',
#               'nibabel',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'requests',
#               'scikit-image',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'shap',
#               'tensorflow',
#               'tifffile',
#               'timm',
#               'torch',
#               'torchvision',
#               'tqdm'},
#              '10.3389/fmicb.2020.619166': {'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.1186/s13040-018-0175-7': {'PathCORE-T',
#               'constants',
#               'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'utils'},
#              '10.1038/s41598-018-27344-x': {'autoreload',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'openbabel',
#               'pandas',
#               'py3dmol',
#               'rdkit',
#               'scikit-learn',
#               'scipy'},
#              '10.1099/mgen.0.000168': {'biopython',
#               'bokeh',
#               'fitter',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pandas-profiling',
#               'patsy',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1128/mBio.01412-20': {'biopython',
#               'matplotlib',
#               'numpy',
#               'openpyxl',
#               'pandas',
#               'scikit-bio',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.3389/fbioe.2020.00893': {'matplotlib',
#               'networkx',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'pdf2image',
#               'reportlab',
#               'scipy',
#               'seaborn'},
#              '10.1371/journal.pone.0221841': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1371/journal.pcbi.1008833': {'PyWavelets',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pdkit',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tslearn'},
#              '10.1128/mSphere.00306-20': {'biopython',
#               'ete3',
#               'ipython',
#               'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn',
#               'statannot',
#               'statsmodels'},
#              '10.1371/journal.pcbi.1005097': {'matplotlib', 'pandas'},
#              '10.1371/journal.pcbi.1007900': {'ipython', 'maboss'},
#              '10.7717/peerj.10316': {'autoreload',
#               'bayesflow',
#               'ipython',
#               'keras',
#               'matplotlib',
#               'numba',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tensorflow',
#               'tqdm'},
#              '10.1371/journal.pcbi.1007549': {'brainiak',
#               'deepdish',
#               'ipython',
#               'matplotlib',
#               'mpi4py',
#               'networkx',
#               'nibabel',
#               'nilearn',
#               'niwidgets',
#               'numpy',
#               'nxviz',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'watchdog'},
#              '10.7717/peerj.7840': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'xgboost'},
#              '10.1371/journal.pone.0225900': {'h5py',
#               'ipython',
#               'matplotlib',
#               'numba',
#               'numpy',
#               'pandas',
#               'pygpc',
#               'pyrates',
#               'scipy',
#               'seaborn'},
#              '10.1016/j.isci.2019.05.025': {'autoreload', 'numpy', 'pandas'},
#              '10.1093/gigascience/giaa046': {'ete2',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'plotly',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1371/journal.pcbi.1006641': {'matplotlib',
#               'numpy',
#               'pystan',
#               'scipy'},
#              '10.1371/journal.pone.0198882': {'autoreload',
#               'biopython',
#               'ete3',
#               'h5py',
#               'ipyparallel',
#               'ipyrad',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-allel',
#               'scipy',
#               'seaborn',
#               'toyplot',
#               'toytree',
#               'vcfnp'},
#              '10.7554/eLife.46935': {'keras',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn',
#               'tensorflow',
#               'vampire'},
#              '10.1007/s43681-021-00081-0': {'PyYAML',
#               'datasets',
#               'krippendorff',
#               'matplotlib',
#               'nltk',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'shap',
#               'torch',
#               'tqdm',
#               'transformers'},
#              '10.1007/s11306-019-1588-0': {'cimcb-lite',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn'},
#              '10.1371/journal.pone.0255085': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'xgboost'},
#              '10.1186/s41235-021-00296-z': {'matplotlib', 'numpy', 'pandas'},
#              '10.3389/fninf.2017.00044': {'matplotlib',
#               'numpy',
#               'samuroi',
#               'scipy'},
#              '10.3389/fninf.2019.00062': {'ipython',
#               'lxml',
#               'matplotlib',
#               'neo',
#               'numpy',
#               'odML',
#               'odmltables',
#               'rdflib',
#               'requests'},
#              '10.7717/peerj-cs.608': {'feather',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'tomotopy'},
#              '10.1186/s13073-021-00910-1': {'matplotlib',
#               'mhcflurry',
#               'mhctools',
#               'pandas',
#               'pepdata',
#               'scikit-learn',
#               'seaborn'},
#              '10.3389/frma.2021.669675': {'Pillow',
#               'biopython',
#               'dask',
#               'ggplot',
#               'ipython',
#               'matplotlib',
#               'networkx',
#               'numba',
#               'numpy',
#               'pandas',
#               'pandas-profiling',
#               'plotnine',
#               'scikit-learn',
#               'scipy'},
#              '10.7554/eLife.31955': {'biopython',
#               'ete3',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.3390/s21134443': {'autoreload',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pymo',
#               'scikit-learn',
#               'tensorflow'},
#              '10.7554/eLife.60416': {'fretbursts',
#               'ipython',
#               'ipywidgets',
#               'lmfit',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'phconvert',
#               'pybroom',
#               'pytest',
#               'scipy'},
#              '10.12688/wellcomeopenres.15853.2': {'autoreload',
#               'matplotlib',
#               'numpy',
#               'omero-py',
#               'requests'},
#              '10.1186/s42523-020-00068-y': {'numpy', 'pandas'},
#              '10.1074/jbc.RA118.005639': {'matplotlib',
#               'pandas',
#               'pystan',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'statsmodels'},
#              '10.1073/pnas.1814338116': {'pandas', 'pybedtools'},
#              '10.7554/eLife.52371': {'matplotlib', 'numpy', 'scipy'},
#              '10.1371/journal.pone.0226461': {'autoreload',
#               'data',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'tensorflow'},
#              '10.1038/s41598-018-36861-8': {'autoreload',
#               'ipython',
#               'matplotlib',
#               'mayavi',
#               'motionclouds',
#               'numpy',
#               'scipy'},
#              '10.3390/vision3040055': {'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'statsmodels'},
#              '10.1371/journal.pone.0217524': {'colicoords',
#               'mahotas',
#               'matplotlib',
#               'numpy',
#               'tifffile'},
#              '10.7554/eLife.61523': {'numpy', 'pandas', 'plotly', 'rpy2'},
#              '10.1093/ve/vez039': {'biopython',
#               'ete3',
#               'ggplot',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy'},
#              '10.1128/JVI.00500-19': {'biopython',
#               'ipython',
#               'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'openpyxl',
#               'pandas',
#               'plotnine',
#               'seaborn'},
#              '10.1038/s41598-018-35399-z': {'autoencoder',
#               'dcor',
#               'matplotlib',
#               'matrix',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'torch'},
#              '10.1038/s41597-021-00986-9': {'ipython',
#               'matplotlib',
#               'monty',
#               'numpy',
#               'pymatgen',
#               'seaborn'},
#              '10.3389/fninf.2018.00090': {'matplotlib',
#               'neo',
#               'networkunit',
#               'numpy',
#               'sciunit',
#               'seaborn'},
#              '10.7554/eLife.42591': {'autoreload',
#               'bcbio-gff',
#               'biopython',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'plotly',
#               'scikit-learn',
#               'seaborn'},
#              '10.1016/j.patter.2021.100213': {'appyter',
#               'ipython',
#               'numpy',
#               'plotly'},
#              '10.1371/journal.ppat.1007159': {'colour',
#               'ipython',
#               'matplotlib',
#               'natsort',
#               'numpy',
#               'pandas',
#               'rpy2'},
#              '10.3389/fninf.2017.00015': {'GitPython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pymatbridge',
#               'requests',
#               'scipy',
#               'seaborn'},
#              '10.1186/s12859-019-2967-2': {'matplotlib', 'numpy', 'pandas'},
#              '10.1371/journal.pcbi.1006157': {'Theano',
#               'autoreload',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scipy',
#               'seaborn',
#               'utils'},
#              '10.3389/fgene.2020.00608': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1016/j.yjsbx.2021.100046': {'altair',
#               'beautifulsoup4',
#               'ipython',
#               'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'renderapi',
#               'scikit-image',
#               'seaborn',
#               'tifffile',
#               'tqdm'},
#              '10.3389/fmicb.2021.719153': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1186/s12859-019-2931-1': {'autoreload',
#               'clodsa',
#               'frimcla',
#               'google',
#               'h5py',
#               'image',
#               'imageio',
#               'imutils',
#               'ipython',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'pycocotools',
#               'scikit-image',
#               'scikit-learn',
#               'tensorflow',
#               'tflearn'},
#              '10.7554/eLife.48779': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1186/s12864-017-3676-8': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1038/sdata.2017.127': {'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.3389/fmicb.2020.00887': {'numpy', 'pandas', 'rpy2'},
#              '10.1371/journal.pcbi.1008063': {'ipython',
#               'libroadrunner',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'tellurium'},
#              '10.1016/j.toxcx.2021.100071': {'Pillow',
#               'PyPDF2',
#               'docx',
#               'fuzzysearch',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'pdf2image',
#               'requests',
#               'tqdm',
#               'utils'},
#              '10.1371/journal.pcbi.1007113': {'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1038/s41598-021-83827-4': {'Pillow',
#               'fastai',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'pyvips',
#               'scikit-learn',
#               'torch',
#               'torchvision',
#               'tqdm',
#               'umap-learn'},
#              '10.3390/s21175896': {'imbalanced-learn',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn',
#               'tensorflow'},
#              '10.1371/journal.pbio.3000495': {'matplotlib', 'numpy', 'scipy'},
#              '10.3389/fcimb.2020.00137': {'autoreload',
#               'ipython',
#               'lxml',
#               'matplotlib',
#               'numpy',
#               'omicexperiment',
#               'pandas',
#               'scikit-bio'},
#              '10.1371/journal.pgen.1006573': {'Cython',
#               'fwdpy',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2'},
#              '10.15252/msb.20209442': {'FlowCytometryTools',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'plotnine',
#               'scikit-learn'},
#              '10.1128/mSystems.00058-19': {'biom-format',
#               'calour',
#               'emperor',
#               'gneiss',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-bio',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1038/s41597-020-0498-3': {'bids',
#               'ipython',
#               'matplotlib',
#               'nibabel',
#               'nilearn',
#               'nipype',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1038/s41597-020-0526-3': {'imageio',
#               'ipywidgets',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'scikit-learn',
#               'tensorflow',
#               'tqdm'},
#              '10.1128/JB.00460-18': {'Theano',
#               'bokeh',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pymc3',
#               'pystan',
#               'scikit-image',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tqdm',
#               'xmltodict'},
#              '10.1016/j.csbj.2020.10.023': {'pandas', 'prodmx'},
#              '10.1038/s41598-020-75899-5': {'ipython',
#               'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas'},
#              '10.1093/gigascience/giaa026': {'imbalanced-learn',
#               'numpy',
#               'pandas',
#               'pmlb'},
#              '10.7717/peerj-cs.156': {'Genderize',
#               'XlsxWriter',
#               'evaluators',
#               'helpers',
#               'matplotlib',
#               'mpltools',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.3390/metabo10100416': {'adjusttext',
#               'bokeh',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn',
#               'tidyms'},
#              '10.1186/s12859-017-1478-2': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.1186/s12859-019-2789-2': {'matplotlib',
#               'ngram',
#               'nltk',
#               'numpy',
#               'pandas',
#               'pycorenlp',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'spacy'},
#              '10.7554/eLife.31209': {'autoreload', 'scipy'},
#              '10.1128/mSystems.00022-16': {'cual-id',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-bio',
#               'scikit-learn',
#               'seaborn'},
#              '10.3389/fpls.2021.609684': {'GSForge',
#               'colorcet',
#               'datashader',
#               'gseapy',
#               'holoviews',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'patsy',
#               'rpy2',
#               'scikit-learn',
#               'seaborn',
#               'umap-learn',
#               'xarray'},
#              '10.3390/genes12020319': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'shap',
#               'torch',
#               'xgboost'},
#              '10.1371/journal.pcbi.1008724': {'gensim',
#               'matchms',
#               'matplotlib',
#               'networking',
#               'networkx',
#               'numpy',
#               'pandas',
#               'rdkit',
#               'seaborn',
#               'spec2vec',
#               'tqdm'},
#              '10.7554/eLife.68335': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1038/s41598-020-76012-6': {'PyYAML',
#               'ipython',
#               'numpy',
#               'pandas'},
#              '10.15252/msb.20198831': {'adjusttext',
#               'biopython',
#               'fastcluster',
#               'goatools',
#               'joypy',
#               'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'pandas',
#               'roman',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1093/gigascience/giab030': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-multiflow'},
#              '10.3390/microorganisms8030437': {'cobra',
#               'est',
#               'lxml',
#               'matplotlib',
#               'pandas'},
#              '10.1371/journal.pbio.2006760': {'bokeh', 'matplotlib', 'numpy'},
#              '10.1371/journal.pone.0215571': {'matplotlib',
#               'numpy',
#               'pandas',
#               'python-dateutil',
#               'scikit-learn',
#               'scipy'},
#              '10.3389/fdata.2019.00019': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy'},
#              '10.1002/aps3.11436': {'Pillow',
#               'PyWavelets',
#               'gouda',
#               'keras',
#               'lensfunpy',
#               'libs',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'piexif',
#               'plaidml',
#               'pyzbar',
#               'rawpy',
#               'tensorflow',
#               'zxing'},
#              '10.12688/f1000research.21508.1': {'matplotlib',
#               'matplotlib-venn',
#               'pandas',
#               'requests'},
#              '10.7554/eLife.54014': {'hddm',
#               'imageio',
#               'ipython',
#               'joblib',
#               'kabuki',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'patsy',
#               'pymc',
#               'scipy',
#               'seaborn',
#               'ssms',
#               'statsmodels',
#               'tqdm'},
#              '10.1371/journal.pgen.1009774': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy'},
#              '10.1002/ece3.4013': {'biopython', 'numpy', 'reprophylo'},
#              '10.1038/s41597-020-0415-9': {'matplotlib',
#               'numpy',
#               'pandas',
#               'pynwb',
#               'rutishauserlabtonwb',
#               'seaborn'},
#              '10.1038/s41597-020-00769-8': {'dask',
#               'h5py',
#               'lmfit',
#               'matplotlib',
#               'mpes',
#               'mpld3',
#               'numpy',
#               'processor',
#               'scipy',
#               'silx',
#               'symmetrize',
#               'tifffile',
#               'tqdm',
#               'xarray'},
#              '10.1016/j.cels.2019.11.006': {'cobra',
#               'ipython',
#               'mackinac',
#               'matplotlib',
#               'medusa',
#               'numpy',
#               'pandas',
#               'psutil',
#               'scikit-bio',
#               'scikit-learn',
#               'scikit-posthocs',
#               'scipy',
#               'seaborn'},
#              '10.3389/fphys.2020.590479': {'maboss', 'matplotlib', 'seaborn'},
#              '10.1039/d0sc05337f': {'GPy',
#               'aiida',
#               'ase',
#               'autoreload',
#               'colormath',
#               'colour',
#               'joblib',
#               'keras',
#               'lightgbm',
#               'livelossplot',
#               'matplotlib',
#               'numpy',
#               'openbabel',
#               'opencv-python',
#               'pandas',
#               'probflow',
#               'pybel',
#               'pymatgen',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'shap',
#               'six',
#               'tensorflow',
#               'tqdm',
#               'umap-learn',
#               'webcolors',
#               'xgboost'},
#              '10.3390/genes10121017': {'Pillow',
#               'PyYAML',
#               'blind',
#               'boto3',
#               'botocore',
#               'configspace',
#               'cuml',
#               'datasets',
#               'diffusers',
#               'evaluate',
#               'fastapi',
#               'feast',
#               'filelock',
#               'gymnasium',
#               'horovod',
#               'hyperopt',
#               'ipython',
#               'lightgbm',
#               'matplotlib',
#               'mxnet',
#               'nevergrad',
#               'numpy',
#               'pandas',
#               'prophet',
#               'pyarrow',
#               'pytesseract',
#               'ray',
#               'requests',
#               'scikit-learn',
#               'scikit-optimize',
#               'scipy',
#               'spacy',
#               'spacy-langdetect',
#               'starlette',
#               'statsforecast',
#               'tensorflow',
#               'torch',
#               'torchmetrics',
#               'torchvision',
#               'transformers',
#               'xformers',
#               'xgboost',
#               'xmltodict',
#               'zoopt'},
#              '10.1186/s12870-021-03070-x': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn'},
#              '10.3390/metabo8010003': {'aikido',
#               'cobra',
#               'db',
#               'igraph',
#               'ipython',
#               'labeling',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pcaplib',
#               'seaborn'},
#              '10.1186/s12859-020-03739-4': {'ipython',
#               'matplotlib',
#               'pandas',
#               'seaborn'},
#              '10.1523/ENEURO.0356-17.2018': {'seaborn'},
#              '10.1093/bioinformatics/btz293': {'ipython',
#               'joblib',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rdkit',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1186/s12874-017-0381-x': {'clintrials',
#               'ggplot',
#               'numpy',
#               'scipy'},
#              '10.7554/eLife.54129': {'adjusttext', 'autoreload', 'matplotlib'},
#              '10.1371/journal.ppat.1009373': {'biopython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pysam',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1029/2019EA001004': {'analysis', 'matplotlib', 'numpy'},
#              '10.7554/eLife.52091': {'matplotlib',
#               'numpy',
#               'openpyxl',
#               'pandas',
#               'scipy'},
#              '10.1371/journal.pcbi.1008243': {'epistasis',
#               'gpmap',
#               'gpseer',
#               'matplotlib',
#               'numpy',
#               'pandas'},
#              '10.1038/s42003-020-0905-5': {'keras',
#               'matplotlib',
#               'mrcnn',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'pyefd',
#               'scikit-image',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tensorflow'},
#              '10.1371/journal.pone.0208561': {'Cython',
#               'autograd',
#               'autoreload',
#               'cirq',
#               'cotengra',
#               'dimod',
#               'fermilib',
#               'fqe',
#               'grove',
#               'ipython',
#               'ipywidgets',
#               'matplotlib',
#               'mock',
#               'networkx',
#               'numpy',
#               'openfermion',
#               'pandas',
#               'pipenv',
#               'projectq',
#               'pyquil',
#               'pyzx',
#               'qiskit',
#               'qubiter',
#               'quimb',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'setuptools',
#               'tensorflow'},
#              '10.7554/eLife.44080': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1186/s12859-020-03802-0': {'matplotlib',
#               'numpy',
#               'pandas',
#               'requests',
#               'seaborn'},
#              '10.1186/s12934-019-1229-3': {'cobra', 'matplotlib', 'numpy'},
#              '10.3389/fphys.2021.693735': {'apiclient',
#               'httplib2',
#               'ipywidgets',
#               'oauth2client',
#               'pandas',
#               'plotly',
#               'python-dateutil',
#               'tqdm'},
#              '10.1186/s12868-019-0538-0': {'matplotlib',
#               'neat',
#               'numpy',
#               'scikit-learn',
#               'torch',
#               'torchvision'},
#              '10.1128/mSystems.00913-20': {'biopython',
#               'cameo',
#               'cobra',
#               'joblib',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'xgboost'},
#              '10.3389/fpls.2021.715309': {'google',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'tensorflow'},
#              '10.1093/gigascience/giaa077': {'bokeh',
#               'hail',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pdbio',
#               'plotly',
#               'pyspark',
#               'scikit-learn',
#               'scipy'},
#              '10.7554/eLife.68346': {'biopython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.12688/f1000research.14612.2': {'requests'},
#              '10.12688/f1000research.23180.2': {'matplotlib',
#               'pandas',
#               'seaborn'},
#              '10.7554/eLife.45403': {'ParmEd',
#               'matplotlib',
#               'mdtraj',
#               'msmbuilder',
#               'msmexplorer',
#               'numpy',
#               'pandas',
#               'pyEMMA',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'simtk',
#               'six'},
#              '10.3390/e23091134': {'GPy',
#               'POT',
#               'autoreload',
#               'celluloid',
#               'ipython',
#               'magic-impute',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'phate',
#               'plotly',
#               'prettytable',
#               'pyro',
#               'scanpy',
#               'scikit-learn',
#               'scipy',
#               'scprep',
#               'scvelo',
#               'seaborn',
#               'torch',
#               'torchvision',
#               'tqdm',
#               'trajectorynet',
#               'utils'},
#              '10.1038/s41598-020-61737-1': {'ipykernel',
#               'matplotlib',
#               'nibabel',
#               'nilearn',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.7554/eLife.57613': {'h5py', 'matplotlib', 'numpy'},
#              '10.1186/s12859-021-04150-3': {'anndata',
#               'bbknn',
#               'h5py',
#               'keras',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scanorama',
#               'scanpy',
#               'scgen',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1371/journal.pcbi.1007148': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1371/journal.pcbi.1009071': {'cytopy',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn',
#               'tensorflow',
#               'tqdm',
#               'xgboost'},
#              '10.1016/j.tig.2017.12.005': {'matplotlib',
#               'numpy',
#               'scikit-allel',
#               'scikit-learn'},
#              '10.1534/genetics.116.195214': {'epistasis',
#               'gpmap',
#               'ipywidgets',
#               'matplotlib',
#               'numpy',
#               'scipy'},
#              '10.7717/peerj.8564': {'brainiak',
#               'matplotlib',
#               'nibabel',
#               'numpy',
#               'scipy'},
#              '10.1002/hbm.25589': {'dyconnmap',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pyedflib',
#               'scikit-learn',
#               'scipy',
#               'tqdm'},
#              '10.1093/database/baaa113': {'SPARQLWrapper',
#               'bravo',
#               'cobra',
#               'ipython',
#               'networkx',
#               'pybravo',
#               'pypath'},
#              '10.1038/s41598-020-70259-9': {'liputils',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'requests',
#               'scikit-learn',
#               'seaborn'},
#              '10.7717/peerj.4088': {'matplotlib',
#               'numpy',
#               'opencv-python',
#               'plantcv'},
#              '10.1186/s12859-019-2612-0': {'matplotlib',
#               'numpy',
#               'scikit-learn',
#               'scipy'},
#              '10.1093/gigascience/giy023': {'matplotlib', 'pandas'},
#              '10.1371/journal.pone.0254532': {'pandas'},
#              '10.1093/braincomms/fcz007': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-posthocs',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1186/s13326-018-0177-x': {'autoreload',
#               'ipython',
#               'matplotlib',
#               'networkx',
#               'pandas'},
# ...
#               'pandas',
#               'seaborn',
#               'statsmodels',
#               'textblob'},
#              '10.7554/eLife.64256': {'PyYAML', 'altair', 'numpy', 'pandas'},
#              '10.3389/fmicb.2016.00907': {'PyFBA'},
#              '10.12688/f1000research.23524.3': {'matplotlib', 'numpy'},
#              '10.3390/cancers12123600': {'ginsim',
#               'maboss',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn'},
#              '10.3390/ijms22062784': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1016/j.cub.2020.02.077': {'FlowCytometryTools',
#               'biopython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1038/s42003-021-02166-2': {'Pillow',
#               'autoreload',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'opencv-python',
#               'pandas',
#               'plotly',
#               'scikit-image',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'yellowbrick'},
#              '10.3390/ma14102575': {'matplotlib', 'numpy', 'tensorflow'},
#              '10.3389/fgene.2020.610798': {'helpers',
#               'ipython',
#               'omics',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'tqdm'},
#              '10.1038/s41597-020-00760-3': {'flywheel',
#               'matplotlib',
#               'numpy',
#               'pandas'},
#              '10.1038/s41598-020-60130-2': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-bio',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.12688/f1000research.17548.2': {'numpy',
#               'omadb',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1038/s42003-020-01622-9': {'brainspace',
#               'matplotlib',
#               'nibabel',
#               'nilearn',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'vtk'},
#              '10.7717/peerj.7249': {'HTSeq', 'numpy'},
#              '10.1038/sdata.2019.12': {'Beeswarm',
#               'Pillow',
#               'bdpy',
#               'google',
#               'h5py',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'tools'},
#              '10.3390/children8010001': {'matplotlib',
#               'numpy',
#               'opencv-python',
#               'openpyxl',
#               'pandas',
#               'prettytable',
#               'psycopg2',
#               'python-dateutil',
#               'scipy',
#               'seaborn',
#               'xlrd'},
#              '10.7554/eLife.59882': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn',
#               'statannot'},
#              '10.1107/S2059798318009191': {'cctbx',
#               'dials',
#               'dxtbx',
#               'matplotlib',
#               'scitbx'},
#              '10.3389/fgene.2021.617282': {'arboreto',
#               'distributed',
#               'pandas',
#               'rpy2'},
#              '10.7554/eLife.60705': {'glam',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pymc3',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.7554/eLife.55308': {'biopython',
#               'matplotlib',
#               'mpathic',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'watermark'},
#              '10.1186/s12859-018-2041-5': {'PyLD', 'requests'},
#              '10.15252/msb.20177678': {'scipy'},
#              '10.3390/ijms20184414': {'ipywidgets',
#               'jupyterthemes',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'plotly',
#               'scanpy',
#               'scikit-learn',
#               'scipy',
#               'sica'},
#              '10.1016/j.dib.2020.105149': {'fastprogress',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.1186/s13100-019-0195-y': {'matplotlib'},
#              '10.1038/s41598-021-85807-0': {'allensdk',
#               'matplotlib',
#               'nbconvert',
#               'nbformat',
#               'nbparameterise',
#               'nibabel',
#               'numpy',
#               'pandas',
#               'pynrrd',
#               'scikit-image',
#               'scipy'},
#              '10.3390/ijerph17249368': {'autoreload',
#               'hlda',
#               'ipython',
#               'ipywidgets',
#               'matplotlib',
#               'nltk',
#               'numpy',
#               'pandas',
#               'wordcloud'},
#              '10.1093/database/baaa050': {'ete3',
#               'gneiss',
#               'numpy',
#               'pandas',
#               'requests'},
#              '10.1093/bioinformatics/btaa726': {'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'requests',
#               'scipy',
#               'seaborn'},
#              '10.7554/eLife.62362': {'FlyBrainLab',
#               'future',
#               'h5py',
#               'ipython',
#               'matplotlib',
#               'networkx',
#               'neurokernel',
#               'numpy',
#               'pandas',
#               'requests',
#               'scipy',
#               'seaborn'},
#              '10.1093/database/baz080': {'ipython', 'pandas'},
#              '10.1371/journal.pone.0228333': {'imageio',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-image',
#               'scipy',
#               'seaborn',
#               'tqdm'},
#              '10.1242/dev.199611': {'PyQt5',
#               'matplotlib',
#               'morgana',
#               'numpy',
#               'pandas',
#               'scikit-image',
#               'scipy',
#               'tqdm'},
#              '10.7554/eLife.61881': {'mapping',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'plotly',
#               'scipy',
#               'tqdm'},
#              '10.1038/s41597-021-00878-y': {'matplotlib',
#               'nltk',
#               'numpy',
#               'pandas',
#               'plotly',
#               'requests',
#               'scikit-learn',
#               'seaborn',
#               'simpletransformers',
#               'wget'},
#              '10.1371/journal.pone.0207967': {'eli5',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'tzlocal'},
#              '10.7554/eLife.65372': {'image3c',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'seaborn',
#               'tensorflow',
#               'tifffile'},
#              '10.1099/mgen.0.000071': {'ProDy',
#               'base',
#               'bcbio-gff',
#               'biomart',
#               'biopython',
#               'epitopepredict',
#               'ipython',
#               'matplotlib',
#               'matplotlib-venn',
#               'numpy',
#               'pandas',
#               'pycirclize',
#               'requests',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'snipgenie',
#               'statsmodels'},
#              '10.1007/978-3-030-53291-8_2': {'buddy',
#               'pandas',
#               'pandas2pgfplots',
#               'spot'},
#              '10.1093/jamiaopen/ooab045': {'SQLAlchemy',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pyodbc',
#               'requests',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'tqdm'},
#              '10.1186/s13321-016-0125-7': {'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rdkit',
#               'scikit-learn',
#               'scipy'},
#              '10.1038/s41597-019-0177-4': {'ipywidgets',
#               'nglview',
#               'template'},
#              '10.1186/s13059-016-0953-9': {'PyLD', 'myvariant', 'utils'},
#              '10.1371/journal.pcbi.1005688': {'clawpack',
#               'emcee',
#               'george',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pdfrw',
#               'rpy2',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'triangle'},
#              '10.1128/mSystems.00050-16': {'Jinja2',
#               'beautifulsoup',
#               'ipython',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pycountry'},
#              '10.1128/AEM.00121-20': {'eli5',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rfpimp',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.3390/microorganisms9020416': {'bokeh',
#               'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.3390/metabo9100200': {'ipython',
#               'ipywidgets',
#               'numpy',
#               'pandas',
#               'pyvis',
#               'rdkit'},
#              '10.1186/s12866-021-02281-4': {'matplotlib',
#               'numpy',
#               'pandas',
#               'plotly',
#               'wget'},
#              '10.1186/s12915-020-00940-y': {'biopython',
#               'ipython',
#               'ipywidgets',
#               'joblib',
#               'numpy',
#               'pandas',
#               'pytablewriter',
#               'rdf',
#               'rdflib',
#               'requests',
#               'termcolor',
#               'tqdm',
#               'widgetsnbextension',
#               'wikidataintegrator'},
#              '10.1371/journal.pcbi.1004389': {'matplotlib', 'numpy', 'scipy'},
#              '10.1371/journal.pone.0250282': {'geneview',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn'},
#              '10.3390/s19010210': {'application',
#               'gumpy',
#               'matplotlib',
#               'numpy',
#               'scikit-learn',
#               'scipy'},
#              '10.1371/journal.pcbi.1007099': {'cobra', 'pandas'},
#              '10.3390/ijms21197102': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'venn'},
#              '10.1093/gbe/evz197': {'rpy2'},
#              '10.1038/s41597-019-0286-0': {'SPARQLWrapper',
#               'datapackage',
#               'goodtables',
#               'ipython',
#               'libChEBIpy',
#               'numpy',
#               'pandas',
#               'plotnine',
#               'rdflib'},
#              '10.1093/gigascience/giy082': {'nibabel',
#               'numpy',
#               'pandas',
#               'scipy'},
#              '10.7554/eLife.61277': {'Brian2',
#               'altair',
#               'autoreload',
#               'brainsmash',
#               'brainspace',
#               'fooof',
#               'goatools',
#               'h5py',
#               'hdf5storage',
#               'matplotlib',
#               'mne',
#               'mygene',
#               'neurodsp',
#               'neurodynex',
#               'nibabel',
#               'numpy',
#               'pandas',
#               'pysurfer',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels',
#               'utils'},
#              '10.7554/eLife.46922': {'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1128/mSystems.00123-17': {'iversions',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.1093/gigascience/giaa128': {'autograd',
#               'igraph',
#               'lifelines',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'rpy2',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1002/btm2.10175': {'Pillow',
#               'matplotlib',
#               'numpy',
#               'opencv-python',
#               'pandas'},
#              '10.1128/mSystems.00635-19': {'matplotlib', 'numpy', 'pandas'},
#              '10.3390/ijms20061432': {'ProDy',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'pyproblib',
#               'scikit-learn',
#               'scipy',
#               'seaborn'},
#              '10.1093/scan/nsz037': {'brainiak',
#               'matplotlib',
#               'nibabel',
#               'nilearn',
#               'numpy',
#               'scipy',
#               'seaborn',
#               'statsmodels'},
#              '10.12688/f1000research.11905.2': {'feather',
#               'matplotlib',
#               'pandas',
#               'seaborn'},
#              '10.3389/fpls.2019.01329': {'cufflinks',
#               'numpy',
#               'pandas',
#               'plotly',
#               'rdkit'},
#              '10.3390/s20082235': {'dtscalibration',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'scipy',
#               'xarray'},
#              '10.1021/acs.chemrev.1c00022': {'adjusttext',
#               'asaplib',
#               'ase',
#               'autoreload',
#               'benchml',
#               'ipython',
#               'matplotlib',
#               'nglview',
#               'numpy',
#               'pandas',
#               'plotly',
#               'rascal',
#               'scikit-learn',
#               'scipy',
#               'tqdm'},
#              '10.1186/s12868-018-0452-x': {'autoreload',
#               'h5py',
#               'ipywidgets',
#               'matplotlib',
#               'morphopy',
#               'networkx',
#               'neurom',
#               'numpy',
#               'pandas',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'watermark'},
#              '10.12688/f1000research.18676.1': {'pysradb'},
#              '10.1186/s40679-016-0031-0': {'ads',
#               'matplotlib',
#               'numpy',
#               'pandas',
#               'seaborn',
#               'tqdm'},
#              '10.7554/eLife.59099': {'matplotlib',
#               'numpy',
#               'scikit-image',
#               'scipy'},
#              '10.7554/eLife.54082': {'matplotlib',
#               'networkx',
#               'numpy',
#               'pandas',
#               'progressbar',
#               'requests',
#               'scikit-learn',
#               'scipy',
#               'seaborn',
#               'tqdm'},
#              '10.1371/journal.pcbi.1006333': {'autoreload',
#               'bunch',
#               'matplotlib',
#               'numpy',
#               'palettable',
#               'pandas',
#               'scipy'},
#              '10.1107/S2052252520008830': {'h5py',
#               'matplotlib',
#               'numpy',
#               'scikit-learn',
#               'scipy',
#               'xgboost'},
#              '10.7554/eLife.56079': {'ipython',
#               'matplotlib',
#               'numpy',
#               'scipy'}})

# %%
import pandas as pd
df = pd.read_json("../../hackathon/pypi_with_mentions.ndjson", lines=True)

# %%
czi_map = {}
for i, row in df.iterrows():
    czi_map[str(row["name"]).lower().replace('-', '_').replace('.', '_')] = row["czi_id"]

# %%
enduser_doi_to_czi_map = defaultdict(set)
unknown_czi = defaultdict(set)

for doi, packages in simplified_packages_by_doi.items():
    for package in packages:
        package = package.lower().replace('-', '_').replace('.', '_')
        if czi_id := czi_map.get(package, None):
            enduser_doi_to_czi_map[doi].add(czi_id)
        else:
            unknown_czi[doi].add(package)

# %%
import json

with open("enduser_doi_to_czi.json", "w") as f:
    json.dump({k: list(v) for k, v in enduser_doi_to_czi_map.items()}, f)

# %%
reduce(or_, unknown_czi.values())
# Out:
# {'abipy',
#  'abutils',
#  'actonet',
#  'adjusttext',
#  'afqinsight',
#  'aicsimageio',
#  'aicssegmentation',
#  'aiida',
#  'allensdk',
#  'amici',
#  'anndata2ri',
#  'apiclient',
#  'appyter',
#  'asaplib',
#  'assimp',
#  'astroml',
#  'autoencoder',
#  'autograd',
#  'autoreload',
#  'awkward',
#  'awkwardql',
#  'azureml',
#  'baselines',
#  'bayesflow',
#  'bdpy',
#  'beakerx',
#  'bebi103',
#  'benchml',
#  'bertviz',
#  'biocommons',
#  'bioexplorer',
#  'blackcellmagic',
#  'bluegraph',
#  'bluepyefe',
#  'bluepysnap',
#  'bluesearch',
#  'bond',
#  'bonesis',
#  'bootstrapped',
#  'botometer',
#  'bqplot',
#  'brainiak',
#  'brainsmash',
#  'brainspace',
#  'branca',
#  'bravado',
#  'brewer2mpl',
#  'brian2tools',
#  'cabean',
#  'calour',
#  'capalyzer',
#  'casq',
#  'celerite',
#  'celluloid',
#  'charcoal',
#  'cimcb',
#  'cirq',
#  'clawpack',
#  'clodsa',
#  'cogent3',
#  'colicoords',
#  'common',
#  'condacolab',
#  'configspace',
#  'constants',
#  'convis',
#  'cotengra',
#  'croissance',
#  'crossref',
#  'ctk',
#  'cuml',
#  'cupy',
#  'cylouvain',
#  'cyrand',
#  'cytopy',
#  'datapackage',
#  'datashader',
#  'dcor',
#  'decouple',
#  'deepdish',
#  'descartes',
#  'diffusers',
#  'distributed',
#  'dnaskittleutils',
#  'easydict',
#  'easyeeg',
#  'epypes',
#  'evaluators',
#  'fastapi',
#  'fastprogress',
#  'feast',
#  'feather',
#  'fermilib',
#  'filelock',
#  'fitter',
#  'flybrains',
#  'flywheel',
#  'fqe',
#  'fretbursts',
#  'frimcla',
#  'frogress',
#  'funowl',
#  'fury',
#  'geoplot',
#  'george',
#  'getmac',
#  'glambox',
#  'gmql',
#  'goodtables',
#  'gouda',
#  'graspy',
#  'grove',
#  'gudhi',
#  'gurobipy',
#  'gym',
#  'gymnasium',
#  'h5pyd',
#  'hail',
#  'hdf5plugin',
#  'hdf5storage',
#  'helpers',
#  'hermione',
#  'hippounit',
#  'hlda',
#  'holoviews',
#  'horovod',
#  'htmlmin',
#  'hvplot',
#  'iambcodes',
#  'image3c',
#  'iminuit',
#  'imports',
#  'ineqpy',
#  'instamatic',
#  'iptk',
#  'ipycanvas',
#  'ipyfilechooser',
#  'ipykernel',
#  'ipymol',
#  'ipympl',
#  'ipytransferfunction',
#  'ipyupload',
#  'ipywebrtc',
#  'ism',
#  'itables',
#  'iversions',
#  'jacobi',
#  'javabridge',
#  'jax',
#  'jnius',
#  'joypy',
#  'jsd',
#  'json2html',
#  'jupyterthemes',
#  'jwt',
#  'kaleido',
#  'kaplanmeier',
#  'kgforge',
#  'layers',
#  'lensfunpy',
#  'libsonata',
#  'litus',
#  'livelossplot',
#  'loguru',
#  'lolopy',
#  'loss',
#  'm2g',
#  'mackinac',
#  'mbuild',
#  'mdai',
#  'mdanalysistests',
#  'meautility',
#  'metaknowledge',
#  'metric',
#  'metroid',
#  'mhctools',
#  'miscnn',
#  'monty',
#  'morgana',
#  'morphio',
#  'morphopy',
#  'morphsnakes',
#  'motionclouds',
#  'moviepy',
#  'movingpandas',
#  'mpathic',
#  'mpbn',
#  'mpltools',
#  'mrcnn',
#  'msmexplorer',
#  'mumot',
#  'mwparserfromhell',
#  'myterial',
#  'natsort',
#  'nbformat',
#  'nbparameterise',
#  'nbtools',
#  'ncpol2sdpa',
#  'ndex2',
#  'neat',
#  'netcdf4',
#  'netpyne',
#  'networkunit',
#  'neurodsp',
#  'neurodynex',
#  'neurokernel',
#  'neurom',
#  'neuronunit',
#  'neurotune',
#  'nevergrad',
#  'niwidgets',
#  'nordic',
#  'notebook',
#  'numcodecs',
#  'nxviz',
#  'oauth2client',
#  'oddt',
#  'odmltables',
#  'omg',
#  'omicexperiment',
#  'openfermion',
#  'optax',
#  'osgeo',
#  'owslib',
#  'packaging',
#  'palettable',
#  'pandas2pgfplots',
#  'pandasql',
#  'pastas',
#  'pathme',
#  'pathos',
#  'pcaplib',
#  'pdbio',
#  'pdfrw',
#  'pdkit',
#  'peakdetect',
#  'periodictable',
#  'petab',
#  'phate',
#  'phylics',
#  'picturedrocks',
#  'piexif',
#  'pixiedust',
#  'plaidml',
#  'pmlb',
#  'prettytable',
#  'probflow',
#  'prodmx',
#  'progressbar',
#  'projectq',
#  'py3dmol',
#  'py4cytoscape',
#  'pybliometrics',
#  'pybravo',
#  'pybroom',
#  'pychomp',
#  'pycirclize',
#  'pycocotools',
#  'pycorenlp',
#  'pycountry',
#  'pycroscopy',
#  'pydotplus',
#  'pyedflib',
#  'pygifsicle',
#  'pyinsar',
#  'pykeen',
#  'pykov',
#  'pylandstats',
#  'pylatexenc',
#  'pymatbridge',
#  'pymed',
#  'pymo',
#  'pymolnetenhancer',
#  'pynsid',
#  'pynwb',
#  'pyod',
#  'pyodbc',
#  'pypandoc',
#  'pypdftk',
#  'pyprind',
#  'pyproblib',
#  'pyquaternion',
#  'pyquil',
#  'pyrates',
#  'pyrdf2vec',
#  'pysapc',
#  'pysces',
#  'pyserialem',
#  'pysmfish',
#  'pystablemotifs',
#  'pytablewriter',
#  'pyupset',
#  'pyversions',
#  'pyvips',
#  'pyzx',
#  'qgrid',
#  'quantities',
#  'quaternion',
#  'qubiter',
#  'quimb',
#  'qutip',
#  'rascal',
#  'rawpy',
#  'reachy',
#  'redo',
#  'renderapi',
#  'reprophylo',
#  'rickpy',
#  'rlp',
#  'robotreviewer',
#  'rocrate',
#  'roman',
#  'rutishauserlabtonwb',
#  'sage',
#  'sampledata',
#  'samuroi',
#  'sbol2',
#  'scaffoldgraph',
#  'scgen',
#  'scifireaders',
#  'sciluigi',
#  'sciunit',
#  'scprep',
#  'scrypt',
#  'scyjava',
#  'selfies',
#  'showit',
#  'sidpy',
#  'simpletransformers',
#  'six',
#  'skdaccess',
#  'sketches',
#  'slugify',
#  'snappy',
#  'snipgenie',
#  'sqlparse',
#  'ssms',
#  'starlette',
#  'statsforecast',
#  'stimulus',
#  'stratipy',
#  'stytra',
#  'svgutils',
#  'targetdb',
#  'tesserocr',
#  'thunder',
#  'tidyms',
#  'timm',
#  'timml',
#  'tnorm',
#  'tomotopy',
#  'torchmetrics',
#  'torchsampler',
#  'trajectorynet',
#  'treesap',
#  'treeswift',
#  'triangle',
#  'unidecode',
#  'urllib3',
#  'vcfnp',
#  'vdw',
#  'vimms',
#  'vincent',
#  'viresclient',
#  'visualkeras',
#  'watchdog',
#  'watermark',
#  'webcolors',
#  'widgetsnbextension',
#  'wikidataintegrator',
#  'wrangle',
#  'xformers',
#  'xmltodict',
#  'yellowbrick',
#  'zoopt'}
